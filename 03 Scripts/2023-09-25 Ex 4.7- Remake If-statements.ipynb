# %% [markdown]
# # Ex 4.7 Deriving New Variables

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
path=r'C:\Users\jecka\2023-09-11 Achievement 4 Python'

# %%
# Import merged file
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df = ords_prods_merged[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Create new column
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\jecka\AppData\Local\Temp\ipykernel_2804\2657500399.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
# Check values
df['prices'].value_counts()
# Out:
# prices
# 10.3    379450
# 6.3     176815
# 1.8      76360
# 1.3      57895
# 7.5      57198
# 5.0      42605
# 14.8     41473
# 9.0      35791
# 3.2      21490
# 12.5     15935
# 14.0     13880
# 12.6     13238
# 4.1      10557
# 2.3      10195
# 13.4      8558
# 2.7       8538
# 4.4       6476
# 8.6       6196
# 6.8       5019
# 4.0       3751
# 4.7       2523
# 3.0       1946
# 5.2       1370
# 1.0       1214
# 10.9      1166
# 9.4        361
# Name: count, dtype: int64

# %%
# Check most expensive product
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## Using Loc() Function

# %%
# Trying the loc function
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\jecka\AppData\Local\Temp\ipykernel_2804\2580380286.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %%
# Checking the subset
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN       196.0                1.0
# 1                  7                   15.0       196.0                1.0
# 2                 12                   21.0       196.0                1.0
# 3                  7                   29.0       196.0                1.0
# 4                 15                   28.0       196.0                1.0
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
# Trying Loc() with current df
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] <= 15) & (ords_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN       196.0                1.0
# 1                  7                   15.0       196.0                1.0
# 2                 12                   21.0       196.0                1.0
# 3                  7                   29.0       196.0                1.0
# 4                 15                   28.0       196.0                1.0
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %%
ords_prods_merged.shape
# Out:
# (32404859, 16)

# %% [markdown]
# ## If-statements with for-loops

# %%
# Create new column
ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Set Loop
result = []

for value in ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Add result to dataframe
ords_prods_merged['busiest_day'] = result

# %%
# Check Values
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
# Check dataframe
ords_prods_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_last_order  product_id  add_to_cart_order  \
# 0                  8                    NaN       196.0                1.0
# 1                  7                   15.0       196.0                1.0
# 2                 12                   21.0       196.0                1.0
# 3                  7                   29.0       196.0                1.0
# 4                 15                   28.0       196.0                1.0
#
#    reordered product_name  aisle_id  department_id  prices _merge  \
# ...

# %% [markdown]
# # Task 4.7
# ## Step 2

# %%
# Set New Loop
result_a = []

for value in ords_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result_a.append("Busiest day")
  elif value == 4 or value == 3:
    result_a.append("Least busy")
  else:
    result_a.append("Regularly busy")

# %%
# Add result_a to dataframe
ords_prods_merged['busiest_days'] = result_a

# %% [markdown]
# ## Step 3 Checking for accuracy

# %%
ords_prods_merged.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2398795        1    prior             2                   3
# 2     473747        1    prior             3                   3
# 3    2254736        1    prior             4                   4
# 4     431534        1    prior             5                   4
# 5    3367565        1    prior             6                   2
# 6     550135        1    prior             7                   1
# 7    3108588        1    prior             8                   1
# 8    2295261        1    prior             9                   1
# 9    2550362        1    prior            10                   4
# 10   2968173       15    prior            15                   1
# 11   1870022       15    prior            17                   2
# 12   1911383       15    prior            18                   2
# ...

# %%
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest day       11864412
# Least busy         7624336
# Name: count, dtype: int64

# %% [markdown]
# ## Step 4 ID busiest hours of the day

# %%
# Check hours of df
ords_prods_merged['order_hour_of_day'].value_counts()
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# ##### Most orders: 10, 11, 14, 15, 13, 12, 16, and 9
# ##### Average orders: 17, 8, 18, 19, 20, 7, 21, and 22
# ##### Fewest orders: 23, 6, 0, 1, 5, 2, 4, and 3

# %%
# Create for-loop with hours
busiest_periods = []

for value in ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    busiest_periods.append("Most orders")
  elif value in [23, 6, 0, 1, 5, 2, 4, 3]:
    busiest_periods.append("Fewest orders")
  else:
    busiest_periods.append("Average orders")

# %%
# Apply to df
ords_prods_merged['busiest_period_of_day'] = busiest_periods

# %% [markdown]
# ## Step 5 print the frequency

# %%
# Checking frequency in comparison to previous
ords_prods_merged['busiest_period_of_day'].value_counts()
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# ## Step 7 Export

# %%
#export to pkl
ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_busy.pkl'))
